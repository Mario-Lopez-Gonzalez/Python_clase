# %% [markdown]
# # LISTA 12 - GRÁFICOS

# %% [markdown]
# ## EJERCICIO 1

# %%
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt
import seaborn as sns
import networkx as nx

x = np.random.randint(low=1, high=100, size=100)
y = np.random.randint(low=1, high=100, size=100)
color = np.random.randint(low=1, high=100, size=100)
size = np.random.randint(low=1, high=100, size=100)*10

plt.figure(figsize=(10, 10))
plt.title("Puntos")
plt.xlabel("X")
plt.ylabel("Y")
plt.scatter(x = x, y = y, 
            c = color, alpha = 0.5,
            marker = ".", s = size, cmap = "plasma")
plt.colorbar()
plt.show()

# %% [markdown]
# Dibuja 100 puntos aleatorios (entre 0 y 100 para ambas coordenadas) con colores y tamaños aleatorios y una transparencia de 0.5.
#
# Tendrás que crear 4 arrays aleatorios de 100 posiciones: uno para las coordenadas x, otro para y, otro para el color de cada punto y un último para el tamaño de cada punto. Para que los puntos no se vean muy pequeños, multiplica el array de tamaños por 10.
#
# Configura el tamaño de la figura a 10 x 10. Para ello, investiga el método .figure() de plt.
#
# Por último, selecciona los colores combinando el array aleatorio y el mapa de color llamado hsv y recuerda mostrar la colorbar.

# %% [markdown]
# ## EJERCICIO 2

# %%
def toHex(RGB):
  tokens = RGB.split(",")
  myhex = "#"
  for token in tokens:
    myhex += format(int(token), '02x') # Formateamos el int([numero]) a un hexadecimal de dos cifras
  return myhex

print(toHex("15,255,14"))
# Out:
# #0fff0e

# %% [markdown]
# Crea una función que dado un color en forma RGB lo transforme en su forma hexadecimal.

# %% [markdown]
# ## EJERCICIO 3

# %%
x = np.linspace(-5*np.pi, 5*np.pi, num=100)
f1 = np.sin(x) / x
f2 = (2*np.sin(x))/x
f3 = -1*(np.sin(x))/x

plt.figure(figsize=(8, 6))
plt.plot(f1, c = "#f06741")
plt.plot(f2, c = "#a4f041")
plt.plot(f3, c = "#8d41f0")
plt.title("3 funciones")
plt.show()

# %% [markdown]
# Dibuja la función sin(x)/x de color #f06741, la función (2sin(x))/x de color #a4f041 y la función -sin(x)/x de color #8d41f0 donde x ∈ ```[-5π, 5π]``` en el mismo plot.
#
# Crea el array x de tamaño 100 con el método .linspace() de numpy.
#
# Haz que el tamaño de la figure sea 8 x 6.

# %% [markdown]
# ## EJERCICIO 4

# %%
x = np.linspace(-5*np.pi, 5*np.pi, num=100)

plt.figure(figsize=(10, 5))

fig, (ax1, ax2, ax3) = plt.subplots(1,3)

f1 = np.sin(x) / x
ax1.plot(f1, c = "#f06741")

f2 = (2*np.sin(x))/x
ax2.plot(f2, c = "#a4f041")

f3 = -1*(np.sin(x))/x
ax3.plot(f3, c = "#8d41f0")

plt.show()

# %% [markdown]
# Dibuja las 3 funciones del ejercicio anterior cada una en un subplot con el método .subplot().
#
# Haz que el tamaño de la figure global sea 10 x 5.

# %% [markdown]
# ## EJERCICIO 5

# %%
options = ["Suspenso", "Aprobado", "Notable", "Excelente"]
count = [20, 10, 45, 25]
min_count = count.index(min(count)) # Saca el indice del valor minimo de la lista
explode = [0] * len(count) # Crea una lista de ceros del tamaño de count
explode[min_count] = 0.2 # Agrega un explode de 0.2 en la posicion del indice del valor minimo i.e. [0,0.2,0,0]
colors = ["#ff2667", "#ff7226", "#26a8ff", "#67ff26"]
plt.pie(count, colors = colors, labels = options, explode= explode, autopct = "%0.1f%%", startangle=45, shadow=True)
plt.title("Ejercicio 5")
plt.show()

# %% [markdown]
# Dibuja un diagrama de sectores con los siguientes datos y los siguientes colores. Añádele un título, etiquetas, sombra, una separación de 0.2 al sector más pequeño, haz que empiece en el ángulo 45 y muestra los porcentajes con un solo decimal.
#
# options = ```["Suspenso", "Aprobado", "Notable", "Excelente"]```
# count = ```[20, 10, 45, 25]```
# colors = ```["#ff2667", "#ff7226", "#26a8ff", "#67ff26"]```

# %% [markdown]
# ## EJERCICIO 6

# %%
import networkx as nx
G = nx.Graph()
G.add_nodes_from("abcde")
G.add_weighted_edges_from([("a", "b", 1), ("a", "c", 2), ("a", "d", 2), ("a", "e", 5), ("b", "e", 4), ("c", "d", 3), ("d", "e", 1)])
fig, ax = plt.subplots()
nx.draw(G, ax=ax, node_color = "#ad80fa", edge_color = "#b1ddf5", font_color = "white", font_weight = "bold", with_labels = True)
plt.show()

# %% [markdown]
# Dibuja el siguiente grafo con los nodos de color #ad80fa, las aristas de color #b1ddf5, el nombre de los nodos de color blanco y en negrita.
# ```
# import networkx as nx
# G = nx.Graph()
# G.add_nodes_from("abcde")
# G.add_weighted_edges_from([("a", "b", 1), ("a", "c", 2), ("a", "d", 2), ("a", "e", 5), ("b", "e", 4), ("c", "d", 3), ("d", "e", 1)])
# ```

# %% [markdown]
# ## EJERCICIO 7

# %%
import networkx as nx
G = nx.Graph()
G.add_nodes_from("abcde")
G.add_weighted_edges_from([("a", "b", 1), ("a", "c", 2), ("a", "d", 2), ("a", "e", 5), ("b", "e", 4), ("c", "d", 3), ("d", "e", 1)])
plt.figure(figsize=(8, 6))
fig, ax = plt.subplots()
node_size = [350 * G.degree(n) for n in G.nodes()] # Por cada nodo en nodos saca el grado y multiplicalo por 350 y metelo en una lista para node_size
nx.draw(G, ax=ax, node_color = "#ad80fa", edge_color = "#b1ddf5", font_color = "white", font_weight = "bold", with_labels = True, node_size = node_size)
plt.show()

# %% [markdown]
# Considera el grafo del ejercicio anterior. El tamaño de los nodos debe ser 350 por el grado del nodo. El tamaño de la figura global debe ser de 8 x 6.

# %% [markdown]
# ## EJERCICIO 8

# %%
import networkx as nx
G = nx.Graph()
G.add_nodes_from("abcde")
G.add_weighted_edges_from([("a", "b", 1), ("a", "c", 2), ("a", "d", 2), ("a", "e", 5), ("b", "e", 4), ("c", "d", 3), ("d", "e", 1)])
plt.figure(figsize=(8, 6))
fig, ax = plt.subplots()
node_size = [350 * G.degree(n) for n in G.nodes()] # Por cada nodo en nodos saca el grado y multiplicalo por 350 y metelo en una lista para node_size
edge_size = [2 * G[u][v]['weight'] for u, v in G.edges()] # Por cada conexion entre nodos (u,v) sacamos su weight con (u,v)["weight"] y lo multiplicamos por 2 y lo metemos en una lista para width
nx.draw(G, ax=ax, node_color = "#ad80fa", edge_color = "#b1ddf5", font_color = "white", font_weight = "bold", with_labels = True, node_size = node_size, width = edge_size)
plt.show()

# %% [markdown]
# Considera el grafo del ejercicio anterior. El grosor de las aristas debe ir acorde al peso de cada arista.

# %% [markdown]
# ## EJERCICIO 9

# %%
plt.figure(figsize=(10, 8))
plt.text(0.2, 0.8, 'LA', fontsize=50, rotation=25, ha='center', va='center', bbox=dict(boxstyle='round', facecolor='#242fff', edgecolor='#242fff', alpha=0.7))
plt.text(0.5, 0.55, 'AVENTURA', fontsize=50, rotation=-15, ha='center', va='center', bbox=dict(boxstyle='round', facecolor='#8a24ff', edgecolor='#8a24ff', alpha=0.7))
plt.text(0.8, 0.3, 'SIGUE', fontsize=50, rotation=10, ha='center', va='center', bbox=dict(boxstyle='round', facecolor='#24fff4', edgecolor='#24fff4', alpha=0.7))
plt.show()

# %% [markdown]
# Investiga el método .text() de plt para añadir texto a un plot.
#
# Añade las siguientes 3 palabras “LA”, “AVENTURA”, “SIGUE”.
#
# La palabra “LA” debe estar en la posición (0.2, 0.8), con tamaño 50 y rotación 25, con alineación vertical y horizontal en el centro, y en una caja de estilo redondo, con color de borde y relleno #242fff y transparencia 0.7.
#
# La palabra “AVENTURA” debe estar en la posición (0.5, 0.55), con tamaño 50 y rotación -15, con alineación vertical y horizontal en el centro, y en una caja de estilo redondo, con color de borde y relleno #8a24ff y transparencia 0.7.
#
# La palabra “SIGUE” debe estar en la posición (0.8, 0.3), con tamaño 50 y rotación 10, con alineación vertical y horizontal en el centro, y en una caja de estilo redondo, con color de borde y relleno #24fff4 y transparencia 0.7.
#
# El tamaño de la figura global debe ser 10 x 8.
